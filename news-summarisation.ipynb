# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Loading Essential libraries 
import warnings
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'
# %config Completer.use_jedi = False # this to force autocompletion 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
def read_data():
    """Read the data."""
    news1_df = pd.read_csv('news_summary.csv', encoding='latin-1', usecols=['headlines', 'text'])
    news2_df = pd.read_csv('news_summary_more.csv', encoding='latin-1')
    
    return pd.concat([news1_df, news2_df], axis=0).reset_index(drop=True)

# %%
df = read_data()

# %%
df.head()
# Out:
#                                            headlines  \
# 0  Daman & Diu revokes mandatory Rakshabandhan in...
# 1  Malaika slams user who trolled her for 'divorc...
# 2  'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3  Aaj aapne pakad liya: LeT man Dujana before be...
# 4  Hotel staff to get training to spot signs of s...
#
#                                                 text
# 0  The Administration of Union Territory Daman an...
# 1  Malaika Arora slammed an Instagram user who tr...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Maharashtra will train their staff t...

# %%
df.tail()
# Out:
#                                                 headlines  \
# 102910  CRPF jawan axed to death by Maoists in Chhatti...
# 102911  First song from Sonakshi Sinha's 'Noor' titled...
# 102912         'The Matrix' film to get a reboot: Reports
# 102913  Snoop Dogg aims gun at clown dressed as Trump ...
# 102914  Madhesi Morcha withdraws support to Nepalese g...
#
#                                                      text
# 102910  A CRPF jawan was on Tuesday axed to death with...
# 102911  'Uff Yeh', the first song from the Sonakshi Si...
# 102912  According to reports, a new version of the 199...
# 102913  A new music video shows rapper Snoop Dogg aimi...
# 102914  Madhesi Morcha, an alliance of seven political...

# %% [markdown]
# ### Lets do some text preprocessing

# %%
# lowercasing all the words
df['headlines'] = df.headlines.apply(lambda x: x.lower())
df['text'] = df.text.apply(lambda x: x.lower())

# %%
# !
import  text_hammer as th
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/yash/playground/ssip_py/news-summarisation.ipynb Cell 9 in 2
#       <a href='vscode-notebook-cell:/Users/yash/playground/ssip_py/news-summarisation.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # !
# ----> <a href='vscode-notebook-cell:/Users/yash/playground/ssip_py/news-summarisation.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> import  text_hammer as th
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/text_hammer/__init__.py:1
# ----> 1 from text_hammer import utils
#       2 from tqdm._tqdm_notebook import tqdm_notebook
#       3 tqdm_notebook.pandas()
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/text_hammer/utils.py:13
#      11 import unicodedata
#      12 from textblob import TextBlob
# ---> 13 import en_core_web_sm
#      15 from sklearn.feature_extraction.text import CountVectorizer
#      17 nlp = en_core_web_sm.load()
#
# ModuleNotFoundError: No module named 'en_core_web_sm'

# %%
# Remove quotes 
def Text_cleaning(df, column):
    column = column
    print(column)
    import re
    """column must be a string value"""
    df[column] = df[column].progress_apply(lambda x: re.sub('"',"'", x))
    df[column] = df[column].progress_apply(lambda x:th.remove_special_chars(x))
    df[column] = df[column].progress_apply(lambda x:th.remove_html_tags(x))
    df[column] = df[column].progress_apply(lambda x: th.remove_urls(x))
    df[column] = df[column].progress_apply(lambda x:th.cont_exp(x))
    df[column] = df[column].progress_apply(lambda x: re.sub('[^a-zA-Z]+',' ', x))
    df[column] = df[column].progress_apply(lambda x:' '.join([x for x in x.split() if len(x)>=2]) )
    return df[column]

# %%
cleaned_headlines= Text_cleaning(df, 'headlines')
# Out:
# headlines
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]

# %%
cleaned_text = Text_cleaning(df, 'text')
# Out:
# text
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]
#   0%|          | 0/102915 [00:00<?, ?it/s]

# %%
cleaned_df = pd.DataFrame({'headlines':cleaned_headlines, 'text':cleaned_text})
cleaned_df.head()
# Out:
#                                            headlines  \
# 0  daman diu revokes mandatory rakshabandhan in o...
# 1  malaika slams user who trolled her for divorci...
# 2    virgin now corrected to unmarried in igims form
# 3  aaj aapne pakad liya let man dujana before bei...
# 4  hotel staff to get training to spot signs of s...
#
#                                                 text
# 0  the administration of union territory daman an...
# 1  malaika arora slammed an instagram user who tr...
# 2  the indira gandhi institute of medical science...
# 3  lashkaretaibas kashmir commander abu dujana wh...
# 4  hotels in maharashtra will train their staff t...

# %%
cleaned_df.to_csv('newgroup_cleaned.csv', index = False)

# %%
cleaned_df = pd.read_csv('./newgroup_cleaned.csv')

# %% [markdown]
# ### Some analysis to decide the max_len_headlines and max_len_text

# %%
plt.figure(figsize=(12, 6))
plt.style.use('ggplot')
plt.subplot(1, 2, 1)
sns.distplot(df['headlines'].str.split().apply(len))
plt.title('Distribution of headlines sentences length')
plt.xlabel('Length')

plt.style.use('ggplot')
plt.subplot(1, 2, 2)
sns.distplot(df['text'].str.split().apply(len))
plt.xlim(0,60)
plt.title('Distribution of text sentences length')
plt.xlabel('Length')
plt.show()

# %%
cleaned_df['headlines'] = cleaned_df.headlines.apply(lambda x: 'sostok '+str(x) + ' eostok')

# %%
cleaned_df.head()
# Out:
#                                            headlines  \
# 0  sostok daman diu revokes mandatory rakshabandh...
# 1  sostok malaika slams user who trolled her for ...
# 2  sostok virgin now corrected to unmarried in ig...
# 3  sostok aaj aapne pakad liya let man dujana bef...
# 4  sostok hotel staff to get training to spot sig...
#
#                                                 text
# 0  the administration of union territory daman an...
# 1  malaika arora slammed an instagram user who tr...
# 2  the indira gandhi institute of medical science...
# 3  lashkaretaibas kashmir commander abu dujana wh...
# 4  hotels in maharashtra will train their staff t...

# %%
cleaned_df['len_headlines'] = cleaned_df.headlines.apply(lambda x: len(x.split()))
cleaned_df['len_text'] = cleaned_df.text.apply(lambda x:len(x.split()))

# %% [markdown]
# #### here for deciding the length of the text we need to understand the distribution of the graph

# %%
# calculation the word count of text and getting percentile vlaues
for i in range(80,100,5):
    var = cleaned_df['len_headlines'].values
    var = np.sort(var, axis = None)
    print('{} percentile value is {}'.format(i, var[int(len(var)*(float(i)/100))]))
    print(("100 percentile value is ", var[-1]))
# Out:
# 80 percentile value is 12
# ('100 percentile value is ', 19)
# 85 percentile value is 13
# ('100 percentile value is ', 19)
# 90 percentile value is 13
# ('100 percentile value is ', 19)
# 95 percentile value is 13
# ('100 percentile value is ', 19)

# %%
max_len_text  = 60

max_len_headlines = 15

# %% [markdown]
# #### This is most important step to filter out those sentences who follows condition

# %%
cleaned_df = cleaned_df[(cleaned_df.len_text <=60)*(cleaned_df.len_headlines <= 15)]

# %%
cleaned_df.shape
# Out:
# (102053, 4)

# %%
cleaned_df.len_text.max()
# Out:
# 60

# %% [markdown]
# #### Dividing our data for train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(
cleaned_df.text, cleaned_df.headlines, test_size = 0.2, random_state = 32, shuffle = True)

# %%
print(X_train.shape, y_test.shape)
# Out:
# (81642,) (20411,)

# %% [markdown]
# ### Time to prepare data

# %%
import keras 
num_words_x= 35000
num_words_y = 25000
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

x_tokenizer = Tokenizer(filters='|', num_words = num_words_x)
y_tokenizer = Tokenizer(filters='|', num_words = num_words_y)

x_tokenizer.fit_on_texts(cleaned_df.text)
y_tokenizer.fit_on_texts(cleaned_df.headlines)

# %%
x_voc = len(x_tokenizer.word_index) + 1
y_voc = len(y_tokenizer.word_index) + 1
# this shows us the number of unique words in our text data

# %%
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_train) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_test) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_len_headlines, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_len_headlines, padding='post')

#convert text sequences into integer sequences (i.e one-hot encodeing all the words)
x_tr_seq    =   x_tokenizer.texts_to_sequences(X_train) 
x_val_seq   =   x_tokenizer.texts_to_sequences(X_test)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_len_text, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_len_text, padding='post')

# %%
print(x_tr.shape, y_tr.shape)
# Out:
# (81642, 60) (81642, 15)

# %% [markdown]
# ### We are going to use word embedding (glove vectors )

# %%
## using 300 dimension word2vec model, since more dimension means more information
glove_vectors = {}
file = open('../input/glove6b/glove.6B.300d.txt', encoding = 'utf-8')
for line in file:
    values = line.split()
    word = values[0]
    vectors = np.asarray(values[1:])
    glove_vectors[word] = vectors
file.close()

# %% [markdown]
# #### if word not available in our glove vector then that word will get 0 weightage

# %%
glove_emb_matrix = np.zeros((num_words_x,300))
glove_emb_matrix.shape
# Out:
# (35000, 300)

# %%
# %%time
for word, index in x_tokenizer.word_index.items():
    if index < num_words_x: # since index starts with zero 
        embedding_vector = glove_vectors.get(word)
        if embedding_vector is not None:
            glove_emb_matrix[index] = embedding_vector
# Out:
# CPU times: user 5.48 s, sys: 15.1 ms, total: 5.49 s
# Wall time: 5.5 s

# %% [markdown]
# #### **i'm not applying word2vec in decoder phase becuase y_train have not that big corpus or not having that much big words vocabulary, and word embedding gives us more generalised and excellent model and accuracy **

# %% [markdown]
# ### Importing libraries for designing our architecture

# %%
from tensorflow.keras import models
import numpy as np
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Bidirectional,Concatenate
from tensorflow.keras.layers import Dense, Flatten,Embedding
from tensorflow.keras import Input
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model
from keras.layers import Input,Dense, Activation, concatenate, Embedding, Flatten, Bidirectional, Concatenate
 
from tensorflow.compat.v1.keras.layers import CuDNNLSTM
from keras import optimizers

# %% [markdown]
# ### This is attention layer and can be used in teacher forcing

# %%
# now we will have to make attention classs
import tensorflow as tf
import os
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import backend as K


class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state
            inputs: (batchsize * 1 * de_in_dim)
            states: (batchsize * 1 * de_latent_dim)
            """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch size * en_seq_len * latent_dim
            W_a_dot_s = K.dot(encoder_out_seq, self.W_a)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>', U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            Ws_plus_Uh = K.tanh(W_a_dot_s + U_a_dot_h)
            if verbose:
                print('Ws+Uh>', Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.squeeze(K.dot(Ws_plus_Uh, self.V_a), axis=-1)
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        
        def context_step(inputs, states):
            """ Step function for computing ci using ei """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        fake_state_c = K.sum(encoder_out_seq, axis=1)
        fake_state_e = K.sum(encoder_out_seq, axis=2)  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
y_tr.shape
# Out:
# (81642, 15)

# %% [markdown]
# ### lets design our model architecture for training

# %%
from keras import backend as K 
K.clear_session() 
latent_dim = 500 

# Encoder 
encoder_inputs = Input(shape=(max_len_text,)) 
enc_emb = Embedding(num_words_x, 300,input_length = x_tr.shape[1],
                    trainable = False, weights = [glove_emb_matrix])(encoder_inputs) 

encoder_lstm_layer = Bidirectional(LSTM(latent_dim, return_state=True, return_sequences = True, 
                                             name = 'lstm_encoder'), merge_mode = 'concat')

encoder_output, forward_h, forward_c, backward_h, backward_c = encoder_lstm_layer(enc_emb)

state_h = Concatenate()([forward_h, backward_h])
state_c = Concatenate()([forward_c, backward_c])
encoder_states = [state_h, state_c]

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(num_words_y,latent_dim, input_length=y_tr.shape[1],trainable  = True) 
dec_emb = dec_emb_layer(decoder_inputs) 

#LSTM using encoder_states as initial state
decoder_lstm_layer = LSTM(2*latent_dim, return_state=True, return_sequences = True, name = 'lstm_decoder')
decoder_output , decoder_h, decoder_c = decoder_lstm_layer(dec_emb,
                                                   initial_state = encoder_states)

attn_layer = AttentionLayer(name = 'attention_layer')

######### -------------Attention layer---------------------------
attn_out, attn_states = attn_layer([encoder_output, decoder_output])
decoder_concat_input = Concatenate(axis=-1, name='concat')([decoder_output, attn_out])



#Dense layer
decoder_dense = TimeDistributed(Dense(num_words_y, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 


model = Model([encoder_inputs,decoder_inputs], decoder_outputs) 
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')                                                          
# using sparse_categorical entropy will solve memory problem                                                          
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 60)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 60, 300)      10500000    input_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   [(None, 60, 1000), ( 3204000     embedding[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 500)    12500000    input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1000)         0           bidirectional[0][1]
#                                                                  bidirectional[0][3]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1000)         0           bidirectional[0][2]
#                                                                  bidirectional[0][4]
# __________________________________________________________________________________________________
# lstm_decoder (LSTM)             [(None, None, 1000), 6004000     embedding_1[0][0]
#                                                                  concatenate[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 1000), 2001000     bidirectional[0][0]
#                                                                  lstm_decoder[0][0]
# __________________________________________________________________________________________________
# concat (Concatenate)            (None, None, 2000)   0           lstm_decoder[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 25000)  50025000    concat[0][0]
# ==================================================================================================
# Total params: 84,234,000
# Trainable params: 73,734,000
# Non-trainable params: 10,500,000
# __________________________________________________________________________________________________

# %% [markdown]
# stacked decoder more often need more epochs for training so for now we will not use them

# %%
plot_model(model, to_file='model.png', show_shapes=True)

# %%
## defining callbacks 
es = EarlyStopping(monitor='val_loss',patience = 10, mode='min', verbose=1)
lr = keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss', patience = 1, mode = 'min', verbose = 1)

# %%
print(x_tr.shape, y_tr.shape)
# Out:
# (81642, 60) (81642, 15)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=10,
                  callbacks=[es,lr],
                  batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/10
# 638/638 [==============================] - 204s 311ms/step - loss: 5.0298 - val_loss: 3.8305
# Epoch 2/10
# 638/638 [==============================] - 196s 307ms/step - loss: 3.5412 - val_loss: 3.3717
# Epoch 3/10
# 638/638 [==============================] - 195s 306ms/step - loss: 2.9287 - val_loss: 3.1297
# Epoch 4/10
# 638/638 [==============================] - 196s 307ms/step - loss: 2.4776 - val_loss: 3.0219
# Epoch 5/10
# 638/638 [==============================] - 196s 308ms/step - loss: 2.1140 - val_loss: 2.9680
# Epoch 6/10
# 638/638 [==============================] - 196s 308ms/step - loss: 1.8037 - val_loss: 2.9628
# Epoch 7/10
# 638/638 [==============================] - 196s 308ms/step - loss: 1.5499 - val_loss: 2.9812
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 8/10
# 638/638 [==============================] - 196s 307ms/step - loss: 1.1876 - val_loss: 2.9528
# Epoch 9/10
# 638/638 [==============================] - 197s 309ms/step - loss: 1.0421 - val_loss: 2.9752
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 10/10
# 638/638 [==============================] - 197s 308ms/step - loss: 0.9525 - val_loss: 2.9824
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.

# %%
plt.plot(history.history['val_loss'], color = 'r')
plt.plot(history.history['loss'], color = 'b')
plt.legend(['val_loss','loss'])
plt.xlim(0,10)
plt.xlabel('epochs')
plt.title('learning curve')
plt.show()

# %% [markdown]
# ### Inference Model

# %%
# Define inference model
encoder_model = Model(encoder_inputs, [encoder_output,state_h, state_c])
plot_model(encoder_model,show_shapes=True)

# %%
# now lets design our decoder model 
decoder_state_input_h = Input(shape=(2*latent_dim,))  # These states are required for feeding back to our next timestep decoder
decoder_state_input_c = Input(shape=(2*latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_hidden_state_input = Input(shape=(max_len_text,2*latent_dim)) # since we are using bidirectional lstm


# Get the embeddings of the decoder sequence
dec_emb= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_output, state_h2, state_c2 = decoder_lstm_layer(dec_emb, initial_state=decoder_states_inputs)

attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_output])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_output, attn_out_inf])


# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs] + [state_h2, state_c2])

# %%
plot_model(decoder_model,show_shapes = True)

# %%
# defined a new variable to change words2index nd index2words
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
# function for prediction of whole sentence by using loop
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out,e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out,e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_len_headlines-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
x_val[0].shape
# Out:
# (60,)

# %%
## Testing phase 
decode_sequence(np.array(x_val[0]).reshape(1,60))
# Out:
# ' govt doubles import duty on products to boost bn'

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_val[i]))
    print("Original summary:",seq2summary(y_val[i]))
    print("Predicted summary:",decode_sequence(x_val[i].reshape(1,max_len_text)))
    print("\n")
# Out:
# Review: the government on tuesday doubled the import duty on as many as textile products to to boost local production indias total textile imports jumped by to record billion last fiscal of which billion were from china the government increased the import duty on other products including fibre and apparels last month
# Original summary: govt doubles import tax on textile products to
# Predicted summary:  govt doubles import duty on products to boost bn
#
#
# Review: telecom regulatory authority of india trai on tuesday gave recommendations on internet telephony on mobile operators network and having provision for making calls by using wifi networks trai pitched internet calling as useful and costeffective alternative for making voice calls and medium to obtain connectivity during calls in case of an inadequate mobile signal
# Original summary: make provisions for wifi calls trai to mobile operators
# Predicted summary:  trai asks up for internet network on internet network
#
#
# Review: indian batsman gautam gambhir said that he will not be retiring from cricket till the time he has passion in him am going to keep going and the day feel that there are no emotions involved in it then would think its time to go gambhir said about retirement gambhir turned years old last sunday
# Original summary: wont retire till have that passion in me gautam gambhir
# Predicted summary:  will be retired from cricket till time gambhir
#
#
# Review: advocate rizwan siddiqui has filed thirdparty fir against the viral fevers tvf founder and ceo arunabh kumar on charges of sexual harassment the police were showing their helplessness by saying that they could not act since the women alleging harassment have not filed an fir said siddiqui this comes after more than five women alleged sexual harassment by kumar
# Original summary: fir against tvf ceo arunabh kumar in sexual harassment row
# Predicted summary:  woman files fir against tvf ceo over sexual harassment
#
#
# Review: cancer research uk scientists have created an online breast cancer calculator that could be used by practitioners to help predict breast cancer risks in women the system basis its prediction on factors including weight age at alcohol consumption use of hormone replacement therapy and genetic data the system has taken into account over genetic indicators of breast cancer
# Original summary: online breast cancer calculator to predict cancer risk made
# Predicted summary:  cancer cancer can be used to predict cancer study
#
#
# Review: the delhi police has booked bsf constable after woman alleged that he was staring and winking at her while they were traveling on dtc bus in delhi after being brought to the police station he was examined and found to be in an inebriated state an fir has been registered in the case and investigation is underway
# Original summary: bsf constable held for staring winking at woman on bus
# Predicted summary:  delhi police booked for not bsf while on bus bus
#
#
# Review: filmmaker hansal mehta has said that for him it is important to be able to make the films he wants to while adding money comes after freedom hansal added would rather be free to tell my stories than to make crazy amount of money he further said that he makes enough money to manage and make living
# Original summary: money comes after freedom to tell stories hansal mehta
# Predicted summary:  it is important to be able to make films films hansal
#
#
# Review: taliban leader has ordered his militants to stop fighting against isis in afghanistan saying that the two terrorist groups share common goals reports said taliban and isis both trying to overthrow afghanistans usbacked government and impose an islamic rule in the country had declared holy war against each other over dominance on the insurgency in the region
# Original summary: taliban reverses stance will not fight against is reports
# Predicted summary:  taliban leader has now isis fighting against isis isis
#
#
# Review: after the amritsar train accident during the dussehra celebrations on friday yearolds mother said she found his body at the civil hospital but his mobile phone worth wallet and gold chain were missing another survivor who lost his threeyearold daughter said he was robbed of his phone while shouting for help for his daughter and critically injured son
# Original summary: injured dead were robbed after amritsar train accident
# Predicted summary:  wife find phone phone after amritsar accident victim
#
#
# Review: the family of late fashion designer kate spade has confirmed that her father earl jr passed away on wednesday one night before her funeral on thursday earl who was had been in failing health and was also heartbroken over the recent death of his beloved daughter kate had committed suicide in her new york apartment two weeks ago
# Original summary: kate father passes away one night before her funeral
# Predicted summary:  late father of father passes away at
#
#
# Review: over amazon employees have signed letter urging ceo jeff bezos to stop the sale of the companys facial recognition software rekognition to police forces in the country companies like ours should not be in the business of facilitating authoritarian surveillance not now not ever the letter read we know bezos is aware of these concerns the letter states
# Original summary: lionel messi named barcelona captain for season
# Predicted summary:  messi to replace as captain who called him new
#
#
# Review: jsw steels joint md rao has said the indian steel industry wont have its jio moment despite the entry of the worlds largest steelmaker arcelormittal the lakshmi mittalled company recently emerged as the winning bidder to acquire essar steel jsw said the entry of arcelormittal would be good for competition as indias steel market has room for growth
# Original summary: arcelormittal cant do jio in indian steel industry jsw steel
# Predicted summary:  indian steel not have to have our life rao
#
#
# Review: the delhi government announced on friday that it will roll out new standard nonac cng buses within the next one year the transport department has been directed to complete the rollout of these buses within months this comes after the environment pollution control authority remarked that the government had done too little to delhis public transport
# Original summary: will roll out new cng buses within year delhi govt
# Predicted summary:  delhi government to get new electric buses
#
#
# Review: former cricketer ravi shastri has slammed the move of mumbai being stripped of its full member status according to the new bcci constitution its joke feel sad that the glorious history tradition and contribution of the association to indian cricket went unnoticed shastri said notably mumbai has been one of the most successful sides with ranji titles
# Original summary: mumbais expulsion as bcci full member joke ravi shastri
# Predicted summary:  ravi shastri slams move to remove bcci from bcci
#
#
# Review: as the cbse declared class exam results on sunday kerala auto drivers partially blind son named ajay raj emerged as topper in the differently abled category with marks keralas lakshmi pv and tamil nadus mv were the second and the third topper in the same category with and marks respectively
# Original summary: auto drivers son tops class in disabled section with
# Predicted summary:  cbse class named class on kerala
#
#
# Review: actor vicky friend singh revealed on koffee with karan that girl who had crush on vicky once came to mumbai from another city to hook up with him however added vicky didnt realise this and ended up up with another girl at the same party that night it and hilarious his friend recounted
# Original summary: girl once came to mumbai to hook up with vicky reveals friend
# Predicted summary:  girl on the that is crush on that she met the city with girl
#
#
# Review: keralas tourist footfall may face decline due to the floods as compared to last year if the tourism sector doesnt pick up from october senior tourism official has said august and september were completely washed out as we saw huge cancellations due to the massive floods said keralas tourism director over people died due to the floods
# Original summary: floodhit kerala may face decline in tourists official
# Predicted summary:  tourist due to floods as floods this year
#
#
# Review: in page response to the us government mark zuckerbergled social media giant facebook has admitted it shared its users data with technology companies including alibaba huawei lenovo and oppo facebook ended partnerships with of these companies facebooks partnerships with apple amazon and eyetracking technology company are due to continue beyond october
# Original summary: facebook admits it shared user data with tech companies
# Predicted summary:  facebook admits it share data with tech firms in page
#
#
# Review: former president pranab mukherjee in his book the coalition years has revealed that after the mumbai attack india called the visiting pakistani foreign minister out of press conference and asked him to leave immediately mukherjee the then external affairs minister even offered an aircraft to take the minister back to his home country
# Original summary: after pak minister was asked to leave india exprez
# Predicted summary:  pranab mukherjee reveals he the president of india
#
#
# Review: upgrad and iiit bangalores post graduate program in machine learning and ai helps students transition to high growth job roles in machine learning and ai delivering an average salary hike personalized support during the program and industryrelevant career guidance have been of these transitions learners have transitioned to engineer roles in companies like mindtree and microsoft
# Original summary: upgrad can help you move to futureready ai ml job roles
# Predicted summary:  upgrad helps students get growth in machine learning
#
#
# Review: in letter to shiv sena politician woman superintendent of district jail in maharashtra reportedly alleged harassment and sexual abuse of women staff members by senior officials the letter also pointed to particular senior jail official who allegedly molested at least to women employees till date however the superintendent has denied sending the letter
# Original summary: maharashtra women jail staff allege sexual abuse by seniors
# Predicted summary:  maha sena chief shows woman in sexual abuse claims reports
#
#
# Review: an indian army from para brigade died during skydiving exercise in uttar pradeshs agra after his parachute failed to open the primary reason assigned was falling from height leading to fatal head injury causing death police said the trooper who hails from haryana is survived by his wife and son
# Original summary: army paratrooper falls to death after parachute doesn open
# Predicted summary:  army from indian army dies in up after his flight fails
#
#
# Review: google may be working on face scanning feature for its assistant that would scan users faces to provide personalised commands on cameraequipped devices as per report further the feature will have support that lets users invite other people to create profiles the report added the updated beta version of google application reportedly revealed this development
# Original summary: google assistant to scan face to personalise commands report
# Predicted summary:  google may working on face for face feature report
#
#
# Review: the supreme court has allowed candidates aged above to take national eligibility cum entrance test neet however it said their admission would be subject to the final outcome of the case on validity of cbses decision to fix upper age limit it further directed national testing agency to extend the deadline for filling neet form by one week
# Original summary: sc allows candidates above to appear for neet
# Predicted summary:  sc allows yrold to neet neet to neet neet
#
#
# Review: deepika padukone while addressing rumours that she was paid more than shahid kapoor and ranveer singh for padmavati said talking about my remuneration isnt exciting but im proud and confident about the money get earlier it was reported that while shahid and ranveer were paid crore each deepika received crore for the film
# Original summary: proud and confident about the money get deepika padukone
# Predicted summary:  im paid more than shahid ranveer deepika
#
#
# Review: apple cofounder steve jobs unveiled the first iphone model designed by apple in the us in while unveiling the product he said every once in while revolutionary product comes along that changes everything and proclaimed it was five years ahead of other mobile phones the opening weekend sales of iphone were estimated at over half million
# Original summary: video shows steve jobs unveiling the first iphone in
# Predicted summary:  apple jobs steve jobs was made by apple apple apple
#
#
# Review: england cricket team will train against unique machine known as to prepare for indian chinaman bowler kuldeep yadav who took five wickets in the first the machine which can replicate any bowling angle was introduced ahead of ashes to prepare for spin legend shane warne kuldeep has taken wickets in his last three is
# Original summary: england turn to bowling machine to counter kuldeep
# Predicted summary:  england team to train in any test machine for kuldeep
#
#
# Review: microsoft which was founded on april invested million in apple to save it from bankruptcy in at the time microsofts market capitalisation was billion whereas apple was valued at billion as per the deal microsoft promised to support microsoft office for the mac while apple agreed to make internet explorer its default web browser
# Original summary: microsoft once invested mn to save apple from bankruptcy
# Predicted summary:  microsoft invests mn in apple to save bn
#
#
# Review: gautam gambhir who announced his retirement on tuesday said he wants to open both batting and bowling in his next life despite all the and pains fears and failures wont mind repeat of this in my next few more few more hundreds few wicket hauls as well he said in video
# Original summary: want to open both batting and bowling in my next life gambhir
# Predicted summary:  want to open and batting and bowling gambhir on retirement
#
#
# Review: an airbnb host in amsterdam has been accused of pushing south african filmmaker steve down flight of stairs for checking out few minutes late video shared by her fellow crew member shows the host saying out out before pushing her and her belongings has reportedly been hospitalised while the host faces prosecution for attempted murder
# Original summary: airbnb host pushes black woman down stairs for late
# Predicted summary:  man accused of using tv of the floor to reach tv flight
#
#
# Review: former indian cricketer sachin tendulkar overtook mohammad azharuddin to become odi crickets highest rungetter in fewer odis than the latter sachin playing in his rd odi against new zealand on october smashed runs to overhaul azharuddins odi runs which had come in odis sachins record as highest odi rungetter is still unbroken
